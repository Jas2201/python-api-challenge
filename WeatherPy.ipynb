# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from config import openweather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\chara\anaconda3\lib\site-packages (0.0.6)
# Requirement already satisfied: kdtree>=0.12 in c:\users\chara\anaconda3\lib\site-packages (from citipy) (0.16)

# %% [markdown]
# #### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 587

# %% [markdown]
# #### Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# #### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={openweather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval")
print ("-" * 15)


# Create counters
record_count = 1
set_count = 1
# Loop through all the cities in list
for index, city in enumerate(cities):
    # Group cities in sets of 50 for loggin purpose
    if (index % 50 == 0 and index >= 50):
        set_count += 1
        record_count = 0
    # Create endpoint URL with each city
    city_url = url + "&q=" + city

    
    # Log the URL and set number
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
    
    
 # Extract out max temp humidity and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        
        # Append the city info into the city data list
        city_data.append({
            "City" :city,
            "Lat" :city_lat,
            "Lng" :city_lng,
            "Max Temp" :city_max_temp,
            "Humidity" :city_humidity,
            "Cloudiness" :city_clouds,
            "Windspeed" :city_wind,
            "Country" :city_country,
            "Date" :city_date  
        })
    except:
        print("City not found. Skipping ...")
        pass
    # Indicate that data loading is complete
        print("-----------------------")
        print("Data Retrieval Complete")
        print("-----------------------")
# Out:
# Beginning Data Retrieval
# ---------------
# Processing Record 1 of Set 1 | lebu
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | kayangel
# Processing Record 4 of Set 1 | port elizabeth
# Processing Record 5 of Set 1 | adamstown
# Processing Record 6 of Set 1 | bethel
# Processing Record 7 of Set 1 | selfoss
# Processing Record 8 of Set 1 | port-aux-francais
# Processing Record 9 of Set 1 | blackmans bay
# Processing Record 10 of Set 1 | grytviken
# Processing Record 11 of Set 1 | dolinsk
# Processing Record 12 of Set 1 | tiksi
# Processing Record 13 of Set 1 | hadibu
# Processing Record 14 of Set 1 | lompoc
# Processing Record 15 of Set 1 | grand falls-windsor
# Processing Record 16 of Set 1 | bhimunipatnam
# Processing Record 17 of Set 1 | ytyk-kyuyel'
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 18 of Set 1 | kruisfontein
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | fuvahmulah
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 21 of Set 1 | colares
# Processing Record 22 of Set 1 | haiku-pauwela
# Processing Record 23 of Set 1 | utrik
# Processing Record 24 of Set 1 | san antonio de pale
# Processing Record 25 of Set 1 | iqaluit
# Processing Record 26 of Set 1 | pasni
# Processing Record 27 of Set 1 | la passe
# Processing Record 28 of Set 1 | ribeira grande
# Processing Record 29 of Set 1 | margate
# Processing Record 30 of Set 1 | margaret river
# Processing Record 31 of Set 1 | dikhil
# Processing Record 32 of Set 1 | aasiaat
# Processing Record 33 of Set 1 | okeho
# Processing Record 34 of Set 1 | vilyuchinsk
# Processing Record 35 of Set 1 | edinburgh of the seven seas
# Processing Record 36 of Set 1 | atafu village
# Processing Record 37 of Set 1 | badger
# Processing Record 38 of Set 1 | limon
# Processing Record 39 of Set 1 | kailua-kona
# Processing Record 40 of Set 1 | dongfeng
# Processing Record 41 of Set 1 | raghunathpur
# Processing Record 42 of Set 1 | alice springs
# Processing Record 43 of Set 1 | georgetown
# Processing Record 44 of Set 1 | waitangi
# Processing Record 45 of Set 1 | weno
# Processing Record 46 of Set 1 | bilibino
# Processing Record 47 of Set 1 | alofi
# Processing Record 48 of Set 1 | coquimbo
# Processing Record 49 of Set 1 | leskovac
# Processing Record 50 of Set 1 | puerto ayora
# Processing Record 0 of Set 2 | pordic
# Processing Record 1 of Set 2 | yellowknife
# Processing Record 2 of Set 2 | narrabri
# Processing Record 3 of Set 2 | alice town
# Processing Record 4 of Set 2 | saurimo
# Processing Record 5 of Set 2 | missoula
# Processing Record 6 of Set 2 | revda
# Processing Record 7 of Set 2 | port alfred
# Processing Record 8 of Set 2 | port mathurin
# Processing Record 9 of Set 2 | hawaiian paradise park
# Processing Record 10 of Set 2 | gadzhiyevo
# Processing Record 11 of Set 2 | qaqortoq
# Processing Record 12 of Set 2 | vorkuta
# Processing Record 13 of Set 2 | whakatane
# Processing Record 14 of Set 2 | perry
# Processing Record 15 of Set 2 | copala
# Processing Record 16 of Set 2 | nova sintra
# Processing Record 17 of Set 2 | talavera de la reina
# Processing Record 18 of Set 2 | suva
# Processing Record 19 of Set 2 | isafjordur
# Processing Record 20 of Set 2 | vila velha
# Processing Record 21 of Set 2 | wailua homesteads
# Processing Record 22 of Set 2 | morehead city
# Processing Record 23 of Set 2 | al khawr
# Processing Record 24 of Set 2 | quepos
# Processing Record 25 of Set 2 | avarua
# Processing Record 26 of Set 2 | yucheng
# Processing Record 27 of Set 2 | west island
# Processing Record 28 of Set 2 | maceio
# Processing Record 29 of Set 2 | nishinoomote
# Processing Record 30 of Set 2 | puerto natales
# Processing Record 31 of Set 2 | lihue
# Processing Record 32 of Set 2 | al hazm
# Processing Record 33 of Set 2 | vorgashor
# Processing Record 34 of Set 2 | sona
# Processing Record 35 of Set 2 | upper dir
# Processing Record 36 of Set 2 | usogorsk
# Processing Record 37 of Set 2 | santarem
# Processing Record 38 of Set 2 | richards bay
# Processing Record 39 of Set 2 | natal
# Processing Record 40 of Set 2 | kimbe
# Processing Record 41 of Set 2 | new norfolk
# Processing Record 42 of Set 2 | mount pearl
# Processing Record 43 of Set 2 | vikindu
# Processing Record 44 of Set 2 | punto fijo
# Processing Record 45 of Set 2 | papatowai
# Processing Record 46 of Set 2 | jayapura
# Processing Record 47 of Set 2 | ad dabbah
# Processing Record 48 of Set 2 | anadyr
# Processing Record 49 of Set 2 | hood river
# Processing Record 0 of Set 3 | den burg
# Processing Record 1 of Set 3 | nar'yan-mar
# Processing Record 2 of Set 3 | ilulissat
# Processing Record 3 of Set 3 | hargeysa
# Processing Record 4 of Set 3 | aykol
# Processing Record 5 of Set 3 | fada
# Processing Record 6 of Set 3 | saint-joseph
# Processing Record 7 of Set 3 | puiesti
# Processing Record 8 of Set 3 | kotlas
# Processing Record 9 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 10 of Set 3 | port augusta
# Processing Record 11 of Set 3 | sirte
# Processing Record 12 of Set 3 | taiohae
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 13 of Set 3 | isangel
# Processing Record 14 of Set 3 | hushitai
# Processing Record 15 of Set 3 | berezovyy
# Processing Record 16 of Set 3 | hammerfest
# Processing Record 17 of Set 3 | kill devil hills
# Processing Record 18 of Set 3 | roma
# Processing Record 19 of Set 3 | koshki
# Processing Record 20 of Set 3 | kerikeri
# Processing Record 21 of Set 3 | flying fish cove
# Processing Record 22 of Set 3 | bredasdorp
# Processing Record 23 of Set 3 | arraial do cabo
# Processing Record 24 of Set 3 | westport
# Processing Record 25 of Set 3 | cooper's town
# Processing Record 26 of Set 3 | ust-nera
# Processing Record 27 of Set 3 | luderitz
# Processing Record 28 of Set 3 | puerto san carlos
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 29 of Set 3 | aktau
# Processing Record 30 of Set 3 | devinuwara
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 31 of Set 3 | nalut
# Processing Record 32 of Set 3 | punta arenas
# Processing Record 33 of Set 3 | rawson
# Processing Record 34 of Set 3 | timbuktu
# Processing Record 35 of Set 3 | the pas
# Processing Record 36 of Set 3 | bikenibeu village
# Processing Record 37 of Set 3 | kapa'a
# Processing Record 38 of Set 3 | ouellah
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 39 of Set 3 | tainan
# Processing Record 40 of Set 3 | polonoling
# Processing Record 41 of Set 3 | college
# Processing Record 42 of Set 3 | balabac
# Processing Record 43 of Set 3 | luganville
# Processing Record 44 of Set 3 | mermoz boabab
# Processing Record 45 of Set 3 | bathsheba
# Processing Record 46 of Set 3 | mammoth lakes
# Processing Record 47 of Set 3 | enewetak
# Processing Record 48 of Set 3 | talnakh
# Processing Record 49 of Set 3 | invercargill
# Processing Record 0 of Set 4 | villafranca de los barros
# Processing Record 1 of Set 4 | rongelap
# Processing Record 2 of Set 4 | darwin
# Processing Record 3 of Set 4 | saint-francois
# Processing Record 4 of Set 4 | kingston
# Processing Record 5 of Set 4 | batouri
# Processing Record 6 of Set 4 | sandpoint
# Processing Record 7 of Set 4 | dabou
# Processing Record 8 of Set 4 | kirakira
# Processing Record 9 of Set 4 | murakami
# Processing Record 10 of Set 4 | port saint john's
# Processing Record 11 of Set 4 | hovd
# Processing Record 12 of Set 4 | salym
# Processing Record 13 of Set 4 | zeya
# Processing Record 14 of Set 4 | zhanibek
# Processing Record 15 of Set 4 | luanda
# Processing Record 16 of Set 4 | aginskoye
# Processing Record 17 of Set 4 | kiama
# Processing Record 18 of Set 4 | pozanti
# Processing Record 19 of Set 4 | longyearbyen
# Processing Record 20 of Set 4 | varzea da palma
# Processing Record 21 of Set 4 | azadshahr
# Processing Record 22 of Set 4 | uturoa
# Processing Record 23 of Set 4 | khadan khak
# Processing Record 24 of Set 4 | greymouth
# Processing Record 25 of Set 4 | afaahiti
# Processing Record 26 of Set 4 | sitka
# Processing Record 27 of Set 4 | rancho palos verdes
# Processing Record 28 of Set 4 | hengchun
# Processing Record 29 of Set 4 | udachny
# Processing Record 30 of Set 4 | hassi messaoud
# Processing Record 31 of Set 4 | thompson
# Processing Record 32 of Set 4 | lewistown
# Processing Record 33 of Set 4 | baotou
# Processing Record 34 of Set 4 | manokwari
# Processing Record 35 of Set 4 | kourou
# Processing Record 36 of Set 4 | sakaraha
# Processing Record 37 of Set 4 | saipan
# Processing Record 38 of Set 4 | dogondoutchi
# Processing Record 39 of Set 4 | abraham's bay
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 40 of Set 4 | gaiman
# Processing Record 41 of Set 4 | st. john's
# Processing Record 42 of Set 4 | shache
# Processing Record 43 of Set 4 | dudinka
# Processing Record 44 of Set 4 | impfondo
# Processing Record 45 of Set 4 | fale old settlement
# Processing Record 46 of Set 4 | callao
# Processing Record 47 of Set 4 | tazovsky
# Processing Record 48 of Set 4 | oyama
# Processing Record 49 of Set 4 | jamestown
# Processing Record 0 of Set 5 | port lincoln
# Processing Record 1 of Set 5 | edna
# Processing Record 2 of Set 5 | port hedland
# Processing Record 3 of Set 5 | hithadhoo
# Processing Record 4 of Set 5 | guerrero negro
# Processing Record 5 of Set 5 | san patricio
# Processing Record 6 of Set 5 | bokoro
# Processing Record 7 of Set 5 | karratha
# Processing Record 8 of Set 5 | east london
# Processing Record 9 of Set 5 | cargados carajos
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 10 of Set 5 | marsh harbour
# Processing Record 11 of Set 5 | selkirk
# Processing Record 12 of Set 5 | laojunmiao
# Processing Record 13 of Set 5 | fray luis beltran
# Processing Record 14 of Set 5 | whitehorse
# Processing Record 15 of Set 5 | fortuna
# Processing Record 16 of Set 5 | waddan
# Processing Record 17 of Set 5 | saldanha
# Processing Record 18 of Set 5 | brookings
# Processing Record 19 of Set 5 | tafuna
# Processing Record 20 of Set 5 | nemuro
# Processing Record 21 of Set 5 | kulhudhuffushi
# Processing Record 22 of Set 5 | sao vicente
# Processing Record 23 of Set 5 | chonchi
# Processing Record 24 of Set 5 | sao raimundo das mangabeiras
# Processing Record 25 of Set 5 | olonkinbyen
# Processing Record 26 of Set 5 | korhogo
# Processing Record 27 of Set 5 | shenjiamen
# Processing Record 28 of Set 5 | novovarshavka
# Processing Record 29 of Set 5 | okhotsk
# Processing Record 30 of Set 5 | arish
# Processing Record 31 of Set 5 | buka
# Processing Record 32 of Set 5 | lai
# Processing Record 33 of Set 5 | kete krachi
# Processing Record 34 of Set 5 | galle
# Processing Record 35 of Set 5 | santa cruz
# Processing Record 36 of Set 5 | bridgewater
# Processing Record 37 of Set 5 | iskateley
# Processing Record 38 of Set 5 | bel ombre
# Processing Record 39 of Set 5 | aykhal
# Processing Record 40 of Set 5 | susuman
# Processing Record 41 of Set 5 | bardai
# Processing Record 42 of Set 5 | northam
# Processing Record 43 of Set 5 | salto de agua
# Processing Record 44 of Set 5 | kharabali
# Processing Record 45 of Set 5 | espargos
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 46 of Set 5 | praia da vitoria
# Processing Record 47 of Set 5 | machico
# Processing Record 48 of Set 5 | ancud
# Processing Record 49 of Set 5 | cananeia
# Processing Record 0 of Set 6 | paita
# Processing Record 1 of Set 6 | aripuana
# Processing Record 2 of Set 6 | pangody
# Processing Record 3 of Set 6 | stanley
# Processing Record 4 of Set 6 | ghat
# Processing Record 5 of Set 6 | papao
# Processing Record 6 of Set 6 | mount gambier
# Processing Record 7 of Set 6 | crane
# Processing Record 8 of Set 6 | kodiak
# Processing Record 9 of Set 6 | nuuk
# Processing Record 10 of Set 6 | misratah
# Processing Record 11 of Set 6 | osa
# Processing Record 12 of Set 6 | tolanaro
# Processing Record 13 of Set 6 | luena
# Processing Record 14 of Set 6 | khandyga
# Processing Record 15 of Set 6 | carbonear
# Processing Record 16 of Set 6 | shulan
# Processing Record 17 of Set 6 | gereshk
# Processing Record 18 of Set 6 | neka
# Processing Record 19 of Set 6 | hamilton
# Processing Record 20 of Set 6 | oranjemund
# Processing Record 21 of Set 6 | oualidia
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 22 of Set 6 | conceicao da barra
# Processing Record 23 of Set 6 | kadnikov
# Processing Record 24 of Set 6 | magadan
# Processing Record 25 of Set 6 | vila franca do campo
# Processing Record 26 of Set 6 | igarka
# Processing Record 27 of Set 6 | whangarei
# Processing Record 28 of Set 6 | launceston
# Processing Record 29 of Set 6 | thief river falls
# Processing Record 30 of Set 6 | maffra
# Processing Record 31 of Set 6 | east ballina
# Processing Record 32 of Set 6 | san
# Processing Record 33 of Set 6 | sanxenxo
# Processing Record 34 of Set 6 | taroa
# Processing Record 35 of Set 6 | palikir - national government center
# Processing Record 36 of Set 6 | walvis bay
# Processing Record 37 of Set 6 | mata-utu
# Processing Record 38 of Set 6 | sechura
# Processing Record 39 of Set 6 | antsiranana
# Processing Record 40 of Set 6 | eirunepe
# Processing Record 41 of Set 6 | codrington
# Processing Record 42 of Set 6 | fengcheng
# Processing Record 43 of Set 6 | cocachacra
# Processing Record 44 of Set 6 | sarandi del yi
# Processing Record 45 of Set 6 | sao joao da barra
# Processing Record 46 of Set 6 | pandan
# Processing Record 47 of Set 6 | junction city
# Processing Record 48 of Set 6 | sucre
# Processing Record 49 of Set 6 | bonthe
# Processing Record 0 of Set 7 | yinchuan
# Processing Record 1 of Set 7 | queenstown
# Processing Record 2 of Set 7 | nicoya
# Processing Record 3 of Set 7 | prainha
# Processing Record 4 of Set 7 | talas
# Processing Record 5 of Set 7 | boa vista
# Processing Record 6 of Set 7 | portland
# Processing Record 7 of Set 7 | dunedin
# Processing Record 8 of Set 7 | oulad teima
# Processing Record 9 of Set 7 | pokachi
# Processing Record 10 of Set 7 | gobabis
# Processing Record 11 of Set 7 | yulinshi
# Processing Record 12 of Set 7 | cabedelo
# Processing Record 13 of Set 7 | vingt cinq
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 14 of Set 7 | astrakhan
# Processing Record 15 of Set 7 | saint-pierre
# Processing Record 16 of Set 7 | klyuchi
# Processing Record 17 of Set 7 | kavaratti
# Processing Record 18 of Set 7 | mogadishu
# Processing Record 19 of Set 7 | dryden
# Processing Record 20 of Set 7 | daoukro
# Processing Record 21 of Set 7 | robertsport
# Processing Record 22 of Set 7 | cockburn town
# Processing Record 23 of Set 7 | misliyah
# Processing Record 24 of Set 7 | minab
# Processing Record 25 of Set 7 | hasaki
# Processing Record 26 of Set 7 | gustavia
# Processing Record 27 of Set 7 | bukoba
# Processing Record 28 of Set 7 | i-n-salah
# Processing Record 29 of Set 7 | mantua
# Processing Record 30 of Set 7 | sierakow
# Processing Record 31 of Set 7 | al artawiyah
# Processing Record 32 of Set 7 | chengde
# Processing Record 33 of Set 7 | thinadhoo
# Processing Record 34 of Set 7 | idaho falls
# Processing Record 35 of Set 7 | paris
# Processing Record 36 of Set 7 | new plymouth
# Processing Record 37 of Set 7 | monrovia
# Processing Record 38 of Set 7 | wattens
# Processing Record 39 of Set 7 | tazacorte
# Processing Record 40 of Set 7 | aguas belas
# Processing Record 41 of Set 7 | carnarvon
# Processing Record 42 of Set 7 | saddle brooke
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 43 of Set 7 | broken hill
# Processing Record 44 of Set 7 | dezhou
# Processing Record 45 of Set 7 | mirnyy
# Processing Record 46 of Set 7 | beyneu
# Processing Record 47 of Set 7 | ain bessem
# Processing Record 48 of Set 7 | batangafo
# Processing Record 49 of Set 7 | cerqueira cesar
# Processing Record 0 of Set 8 | laguna
# Processing Record 1 of Set 8 | sao mateus
# Processing Record 2 of Set 8 | qaisumah
# Processing Record 3 of Set 8 | ahau
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 4 of Set 8 | sogod
# Processing Record 5 of Set 8 | chiredzi
# Processing Record 6 of Set 8 | labytnangi
# Processing Record 7 of Set 8 | sinabang
# Processing Record 8 of Set 8 | conde
# Processing Record 9 of Set 8 | chandla
# Processing Record 10 of Set 8 | imst
# Processing Record 11 of Set 8 | carauari
# Processing Record 12 of Set 8 | mugia
# Processing Record 13 of Set 8 | mindresti
# Processing Record 14 of Set 8 | jizzax
# Processing Record 15 of Set 8 | ta`u
# Processing Record 16 of Set 8 | hayma'
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 17 of Set 8 | amga
# Processing Record 18 of Set 8 | ingeniero jacobacci
# Processing Record 19 of Set 8 | bengkulu
# Processing Record 20 of Set 8 | polyarnyy
# Processing Record 21 of Set 8 | ocean pointe
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 22 of Set 8 | boende
# Processing Record 23 of Set 8 | severnoye
# Processing Record 24 of Set 8 | zaraza
# Processing Record 25 of Set 8 | nogliki
# Processing Record 26 of Set 8 | glen innes
# Processing Record 27 of Set 8 | marabba
# Processing Record 28 of Set 8 | 'amran
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 29 of Set 8 | linhares
# Processing Record 30 of Set 8 | kataragama
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 31 of Set 8 | itabira
# Processing Record 32 of Set 8 | tawau
# Processing Record 33 of Set 8 | cabo san lucas
# Processing Record 34 of Set 8 | syumsi
# Processing Record 35 of Set 8 | urucui
# Processing Record 36 of Set 8 | keflavik
# Processing Record 37 of Set 8 | egilsstadir
# Processing Record 38 of Set 8 | sur
# Processing Record 39 of Set 8 | poronaysk
# Processing Record 40 of Set 8 | hermanus
# Processing Record 41 of Set 8 | greenville
# Processing Record 42 of Set 8 | geraldton
# Processing Record 43 of Set 8 | petrosino
# Processing Record 44 of Set 8 | nowogard
# Processing Record 45 of Set 8 | belmonte
# Processing Record 46 of Set 8 | sumbawa besar
# Processing Record 47 of Set 8 | persembe
# Processing Record 48 of Set 8 | port douglas
# Processing Record 49 of Set 8 | alotau
# Processing Record 0 of Set 9 | maintirano
# Processing Record 1 of Set 9 | felidhoo
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 2 of Set 9 | zhezqazghan
# Processing Record 3 of Set 9 | la junta
# Processing Record 4 of Set 9 | chibougamau
# Processing Record 5 of Set 9 | newman
# Processing Record 6 of Set 9 | jeju city
# Processing Record 7 of Set 9 | pimenta bueno
# Processing Record 8 of Set 9 | mogocha
# Processing Record 9 of Set 9 | lautoka
# Processing Record 10 of Set 9 | vredendal
# Processing Record 11 of Set 9 | balqash
# Processing Record 12 of Set 9 | ar rahad
# Processing Record 13 of Set 9 | urengoy
# Processing Record 14 of Set 9 | mtwara
# Processing Record 15 of Set 9 | howard springs
# Processing Record 16 of Set 9 | minas de marcona
# Processing Record 17 of Set 9 | kenai
# Processing Record 18 of Set 9 | megalopoli
# Processing Record 19 of Set 9 | raurkela
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 20 of Set 9 | konarka
# Processing Record 21 of Set 9 | mafinga
# Processing Record 22 of Set 9 | naze
# Processing Record 23 of Set 9 | puerto ayacucho
# Processing Record 24 of Set 9 | caleta olivia
# Processing Record 25 of Set 9 | karema
# Processing Record 26 of Set 9 | rossosh'
# Processing Record 27 of Set 9 | mariental
# Processing Record 28 of Set 9 | banda aceh
# Processing Record 29 of Set 9 | harper
# Processing Record 30 of Set 9 | ario de rosales
# Processing Record 31 of Set 9 | 'ohonua
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 32 of Set 9 | as suwayrah
# Processing Record 33 of Set 9 | pacasmayo
# Processing Record 34 of Set 9 | cedeira
# Processing Record 35 of Set 9 | adrar
# Processing Record 36 of Set 9 | paungde
# Processing Record 37 of Set 9 | mount vernon
# Processing Record 38 of Set 9 | smithers
# Processing Record 39 of Set 9 | sitia
# Processing Record 40 of Set 9 | thetford-mines
# Processing Record 41 of Set 9 | ijuw
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 42 of Set 9 | xiongzhou
# Processing Record 43 of Set 9 | constantia
# Processing Record 44 of Set 9 | malanje
# Processing Record 45 of Set 9 | sheridan
# Processing Record 46 of Set 9 | cururupu
# Processing Record 47 of Set 9 | panaba
# Processing Record 48 of Set 9 | andergrove
# Processing Record 49 of Set 9 | langepas
# Processing Record 0 of Set 10 | kyzyl
# Processing Record 1 of Set 10 | cuenca
# Processing Record 2 of Set 10 | ugoofaaru
# Processing Record 3 of Set 10 | puerto baquerizo moreno
# Processing Record 4 of Set 10 | ust-tsilma
# Processing Record 5 of Set 10 | staroaleyskoye
# Processing Record 6 of Set 10 | odemira
# Processing Record 7 of Set 10 | kalety
# Processing Record 8 of Set 10 | kapuskasing
# Processing Record 9 of Set 10 | arrifes
# Processing Record 10 of Set 10 | muravlenko
# Processing Record 11 of Set 10 | tommot
# Processing Record 12 of Set 10 | takab
# Processing Record 13 of Set 10 | itamaraca
# Processing Record 14 of Set 10 | colonia
# Processing Record 15 of Set 10 | holualoa
# Processing Record 16 of Set 10 | sonsorol village
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 17 of Set 10 | vadso
# Processing Record 18 of Set 10 | nizhnesortymskiy
# Processing Record 19 of Set 10 | justo daract
# Processing Record 20 of Set 10 | chernyshevsk
# Processing Record 21 of Set 10 | terrace
# Processing Record 22 of Set 10 | happy valley-goose bay
# Processing Record 23 of Set 10 | puerto armuelles
# Processing Record 24 of Set 10 | kolonia
# Processing Record 25 of Set 10 | pospelikha
# Processing Record 26 of Set 10 | prince rupert
# Processing Record 27 of Set 10 | claudio
# Processing Record 28 of Set 10 | pemba
# Processing Record 29 of Set 10 | carmi
# Processing Record 30 of Set 10 | fonadhoo
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 31 of Set 10 | nema
# Processing Record 32 of Set 10 | toliara
# Processing Record 33 of Set 10 | patan
# Processing Record 34 of Set 10 | ola
# Processing Record 35 of Set 10 | touros
# Processing Record 36 of Set 10 | holbrook
# Processing Record 37 of Set 10 | labrador city
# Processing Record 38 of Set 10 | prado
# Processing Record 39 of Set 10 | tindouf
# Processing Record 40 of Set 10 | masterton
# Processing Record 41 of Set 10 | barcelos
# Processing Record 42 of Set 10 | xinyuan
# Processing Record 43 of Set 10 | mana
# Processing Record 44 of Set 10 | yirol
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 45 of Set 10 | yatou
# Processing Record 46 of Set 10 | bata
# Processing Record 47 of Set 10 | imbituba
# Processing Record 48 of Set 10 | kapit
# Processing Record 49 of Set 10 | dhuusamarreeb
# Processing Record 0 of Set 11 | fort mcmurray
# Processing Record 1 of Set 11 | qamdo
# Processing Record 2 of Set 11 | verkhnevilyuysk
# Processing Record 3 of Set 11 | mwene-ditu
# Processing Record 4 of Set 11 | marina di pisa-tirrenia-calambrone
# Processing Record 5 of Set 11 | brisas de zicatela
# Processing Record 6 of Set 11 | korla
# Processing Record 7 of Set 11 | buzuluk
# Processing Record 8 of Set 11 | nkurenkuru
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 9 of Set 11 | pisco
# Processing Record 10 of Set 11 | forster
# Processing Record 11 of Set 11 | hirara
# Processing Record 12 of Set 11 | nhlangano
# Processing Record 13 of Set 11 | shingu
# Processing Record 14 of Set 11 | camana
# Processing Record 15 of Set 11 | tyukhtet
# Processing Record 16 of Set 11 | freistadt
# Processing Record 17 of Set 11 | dalaba
# Processing Record 18 of Set 11 | saudarkrokur
# Processing Record 19 of Set 11 | ilha solteira
# Processing Record 20 of Set 11 | divnomorskoye
# Processing Record 21 of Set 11 | akureyri
# Processing Record 22 of Set 11 | west side highway
# Processing Record 23 of Set 11 | nhamunda
# Processing Record 24 of Set 11 | taltal
# Processing Record 25 of Set 11 | ngara
# Processing Record 26 of Set 11 | tsiombe
# Processing Record 27 of Set 11 | tshikapa
# Processing Record 28 of Set 11 | lorengau
# Processing Record 29 of Set 11 | bay roberts
# Processing Record 30 of Set 11 | lesnoy
# Processing Record 31 of Set 11 | opuwo
# Processing Record 32 of Set 11 | meizhou
# Processing Record 33 of Set 11 | ataq
# Processing Record 34 of Set 11 | bubaque
# Processing Record 35 of Set 11 | outokumpu
# Processing Record 36 of Set 11 | sovetskiy
# Processing Record 37 of Set 11 | shijiang
# Processing Record 38 of Set 11 | huarmey
# Processing Record 39 of Set 11 | nanlong
# Processing Record 40 of Set 11 | katsuren-haebaru
# Processing Record 41 of Set 11 | mahenge
# Processing Record 42 of Set 11 | general acha
# Processing Record 43 of Set 11 | sittwe
# Processing Record 44 of Set 11 | yuzhno-kurilsk
# Processing Record 45 of Set 11 | krokek
# Processing Record 46 of Set 11 | trinity beach
# Processing Record 47 of Set 11 | rahon
# Processing Record 48 of Set 11 | attapeu
# Processing Record 49 of Set 11 | aroma
# Processing Record 0 of Set 12 | americus
# Processing Record 1 of Set 12 | dubbo
# Processing Record 2 of Set 12 | cox's bazar
# Processing Record 3 of Set 12 | mossel bay
# Processing Record 4 of Set 12 | viedma
# Processing Record 5 of Set 12 | phan rang-thap cham
# Processing Record 6 of Set 12 | lazaro cardenas
# Processing Record 7 of Set 12 | veracruz
# Processing Record 8 of Set 12 | acarau
# Processing Record 9 of Set 12 | hayes
# Processing Record 10 of Set 12 | international falls
# Processing Record 11 of Set 12 | ouadda
# Processing Record 12 of Set 12 | miguel ahumada
# Processing Record 13 of Set 12 | tura
# Processing Record 14 of Set 12 | horad zhodzina
# Processing Record 15 of Set 12 | lethem
# Processing Record 16 of Set 12 | noumea
# Processing Record 17 of Set 12 | ambon
# Processing Record 18 of Set 12 | la toma
# Processing Record 19 of Set 12 | waingapu
# Processing Record 20 of Set 12 | tual
# Processing Record 21 of Set 12 | yamada
# Processing Record 22 of Set 12 | lerwick
# Processing Record 23 of Set 12 | puerto del rosario
# Processing Record 24 of Set 12 | trail
# Processing Record 25 of Set 12 | blackwater
# Processing Record 26 of Set 12 | fereydun kenar
# Processing Record 27 of Set 12 | george town
# Processing Record 28 of Set 12 | enriquillo
# Processing Record 29 of Set 12 | illizi
# Processing Record 30 of Set 12 | ntcheu
# Processing Record 31 of Set 12 | castro
# Processing Record 32 of Set 12 | arkhangel'sk
# Processing Record 33 of Set 12 | bovalino
# Processing Record 34 of Set 12 | youghal
# Processing Record 35 of Set 12 | tobi village
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 36 of Set 12 | sao jose da coroa grande

# %%
# Convert the cities weather data into a Pandas DataFrame

city_data_df = pd.read_csv("C:/Users/chara/Downloads/city_data.csv")


# Extract relevant fields from the data frame
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

#city_data_df.to_csv(city_data_df, index_label="City_ID")

# Show Record Count
city_data_df.count()
# Out:
# City_ID       577
# City          577
# Lat           577
# Lng           577
# Max Temp      577
# Humidity      577
# Cloudiness    577
# Wind Speed    577
# Country       574
# Date          577
# dtype: int64

# %%
# Display the city Data Frame
city_data_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0         faya  18.3851   42.4509     22.06        35          21
# 1        1      farsund  58.0948    6.8047     13.30       100           0
# 2        2  new norfolk -42.7826  147.0587     11.72        58          12
# 3        3    jamestown  42.0970  -79.2353      5.77        77         100
# 4        4      lanzhou  36.0564  103.7922     14.53        48          59
#
#    Wind Speed Country        Date
# 0        2.60      SA  1666108228
# 1        7.65      NO  1666108228
# 2        1.34      AU  1666108230
# 3        9.77      US  1666107934
# 4        1.20      CN  1666108230

# %% [markdown]
# #### Create the Scatter Plots Requested
#
# ##### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(lats,
            max_temps,
           edgecolor="black", linewidth=1, marker="o",
           alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude Vs. Max Temperature(%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save figure
#plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build scatter plot for latitude vs. Humidity
plt.scatter(lats,
            humidity,
           edgecolor="black", linewidth=1, marker="o",
           alpha=0.8, label="Cities")


# Incorporate the other graph properties
plt.title("City Latitude Vs. Humidity(%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)


# Save figure
#plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build scatter plot for latitude vs. Cloudiness
plt.scatter(lats,
            cloudiness,
           edgecolor="black", linewidth=1, marker="o",
           alpha=0.8, label="Cities")


# Incorporate the other graph properties
plt.title("City Latitude Vs. Cloudiness(%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)


# Save figure
#plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# ##### Latitude vs. Wind Speed Plot

# %%
# Build scatter plot for latitude vs. Windspeed
plt.scatter(lats,
            wind_speed,
           edgecolor="black", linewidth=1, marker="o",
           alpha=0.8, label="Cities")


# Incorporate the other graph properties
plt.title("City Latitude Vs. Wind Speed(%s)" % time.strftime("%x"))
plt.ylabel("Windspeed mph")
plt.xlabel("Latitude")
plt.grid(True)


# Save figure
#plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ### Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values,y_values,title,text_coordinates):
    
    # Run regression on Southern Hemisphere
    (slope, intercept, rvalue, pvalue, stderr) = linregress (x_values,y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + " x + " + str(round(intercept,2))
    
    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq,text_coordinates, fontsize=15, color="red")
    plt.xlabel("Latitude")
    plt.ylabel("Title")
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)

northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] <0)]

# %% [markdown]
# ####  Temperature vs. Latitude Linear Regression Plot

# %%
x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Max Temp"]
plot_linear_regression(x_values,y_values, 'Max Temp', (6,30))
# Out:
# The r-squared is: -0.8462548186825364

# %% [markdown]
# ### Linear regression on Southern Hemisphere

# %%
x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Max Temp"]
plot_linear_regression(x_values,y_values, 'Max Temp', (-30,40))
# Out:
# The r-squared is: 0.6419546065421801

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
#Northern Hemisphere
x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Humidity"]
plot_linear_regression(x_values,y_values, 'Humidity', (40,10))
# Out:
# The r-squared is: 0.2385317912939407

# %%
# Southern Hemisphere
x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Humidity"]
plot_linear_regression(x_values,y_values, 'Humidity', (-30,150))
# Out:
# The r-squared is: 0.016759316950056818

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Cloudiness"]
plot_linear_regression(x_values,y_values, 'Cloudiness', (40,10))
# Out:
# The r-squared is: 0.155004893876971

# %%
#Southern Hemisphere
x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Cloudiness"]
plot_linear_regression(x_values,y_values, 'Cloudiness', (-30,30))
# Out:
# The r-squared is: 0.14341322916643243

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Wind Speed"]
plot_linear_regression(x_values,y_values, 'Windspeed', (40,25))
# Out:
# The r-squared is: 0.1743466729090334

# %%
# Southern Hemisphere
x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Wind Speed"]
plot_linear_regression(x_values,y_values, 'Windspeed', (-30,30))
# Out:
# The r-squared is: -0.24947753546264592
